# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
import pandas as pd

# %%
client_id= "2532039cdb304f01bb5366c20830cdc6"
client_secret= "9cc6f6d754574029ac9690fe08c9dc74"

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
 

song = "Shape Of You" #chosen artist
artist = "Ed Sheeran"


result = sp.search(q=f'artist:{artist} track:{song}') #search query

# id_ = result['tracks']['items'][0]['id']

result['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3T4tUhGYeRNVUGevb0wThu'},
#    'href': 'https://api.spotify.com/v1/albums/3T4tUhGYeRNVUGevb0wThu',
#    'id': '3T4tUhGYeRNVUGevb0wThu',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ba5db46f4b838ef6027e6f96',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ba5db46f4b838ef6027e6f96',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851ba5db46f4b838ef6027e6f96',
#      'width': 64}],
#    'name': '÷ (Deluxe)',
#    'release_date': '2017-03-03',
#    'release_date_precision': 'day',
#    'total_tracks': 16,
#    'type': 'album',
#    'uri': 'spotify:album:3T4tUhGYeRNVUGevb0wThu'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 233712,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS1600463'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7qiZfU4dY1lWllzX7mPBI3'},
#   'href': 'https://api.spotify.com/v1/tracks/7qiZfU4dY1lWllzX7mPBI3',
#   'id': '7qiZfU4dY1lWllzX7mPBI3',
#   'is_local': False,
#   'name': 'Shape of You',
#   'popularity': 86,
#   'preview_url': 'https://p.scdn.co/mp3-preview/84462d8e1e4d0f9e5ccd06f0da390f65843774a2?cid=2532039cdb304f01bb5366c20830cdc6',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:7qiZfU4dY1lWllzX7mPBI3'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7oJa8bPFKVbq4c7NswXHw8'},
#    'href': 'https://api.spotify.com/v1/albums/7oJa8bPFKVbq4c7NswXHw8',
#    'id': '7oJa8bPFKVbq4c7NswXHw8',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27383e9b06ccd219248b5301264',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0283e9b06ccd219248b5301264',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485183e9b06ccd219248b5301264',
#      'width': 64}],
#    'name': 'Shape of You',
#    'release_date': '2017-01-06',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:7oJa8bPFKVbq4c7NswXHw8'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 233712,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS1600463'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/0FE9t6xYkqWXU2ahLh6D8X'},
#   'href': 'https://api.spotify.com/v1/tracks/0FE9t6xYkqWXU2ahLh6D8X',
#   'id': '0FE9t6xYkqWXU2ahLh6D8X',
#   'is_local': False,
#   'name': 'Shape of You',
#   'popularity': 71,
#   'preview_url': 'https://p.scdn.co/mp3-preview/84462d8e1e4d0f9e5ccd06f0da390f65843774a2?cid=2532039cdb304f01bb5366c20830cdc6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:0FE9t6xYkqWXU2ahLh6D8X'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5Nk90vGwn59ToxTvSNsKZw'},
#    'href': 'https://api.spotify.com/v1/albums/5Nk90vGwn59ToxTvSNsKZw',
#    'id': '5Nk90vGwn59ToxTvSNsKZw',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c1c4353f16efbdfde1e819f2',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c1c4353f16efbdfde1e819f2',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c1c4353f16efbdfde1e819f2',
#      'width': 64}],
#    'name': 'Shape of You (Acoustic)',
#    'release_date': '2017-02-10',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:5Nk90vGwn59ToxTvSNsKZw'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 223573,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS1700200'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5ULRlgiSPSKTaJN1vU9yso'},
#   'href': 'https://api.spotify.com/v1/tracks/5ULRlgiSPSKTaJN1vU9yso',
#   'id': '5ULRlgiSPSKTaJN1vU9yso',
#   'is_local': False,
#   'name': 'Shape of You - Acoustic',
#   'popularity': 64,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cb51ebbff7000a306fa82db4c8a9e22f353fa930?cid=2532039cdb304f01bb5366c20830cdc6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5ULRlgiSPSKTaJN1vU9yso'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0LWRykrSX54AWiMZlV5uUk'},
#    'href': 'https://api.spotify.com/v1/albums/0LWRykrSX54AWiMZlV5uUk',
#    'id': '0LWRykrSX54AWiMZlV5uUk',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/621d2909bcc2c26cd0b274aab0414c9d422a1576',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/c976bfc96d5e44820e553a16a6097cd02a61fd2f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/089726b25ce5a55b906b3b65580a517b65c7c881',
#      'width': 64}],
#    'name': 'Shape of You (feat. Zion & Lennox) [Latin Remix]',
#    'release_date': '2017-03-01',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:0LWRykrSX54AWiMZlV5uUk'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2jBa39W2cucJozDpEBtCXu'},
#     'href': 'https://api.spotify.com/v1/artists/2jBa39W2cucJozDpEBtCXu',
#     'id': '2jBa39W2cucJozDpEBtCXu',
#     'name': 'Lennox',
#     'type': 'artist',
#     'uri': 'spotify:artist:2jBa39W2cucJozDpEBtCXu'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7uS0OYJ72fRQDd8RZEo4J0'},
#     'href': 'https://api.spotify.com/v1/artists/7uS0OYJ72fRQDd8RZEo4J0',
#     'id': '7uS0OYJ72fRQDd8RZEo4J0',
#     'name': 'Zion',
#     'type': 'artist',
#     'uri': 'spotify:artist:7uS0OYJ72fRQDd8RZEo4J0'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 237664,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS1700245'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5nCtCCB5i1OfbADvynNw0i'},
#   'href': 'https://api.spotify.com/v1/tracks/5nCtCCB5i1OfbADvynNw0i',
#   'id': '5nCtCCB5i1OfbADvynNw0i',
#   'is_local': False,
#   'name': 'Shape of You (feat. Zion & Lennox) - Latin Remix',
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/0b407c654c3f5b87f925b55c10859c96874c23d6?cid=2532039cdb304f01bb5366c20830cdc6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:5nCtCCB5i1OfbADvynNw0i'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/5j1qqBBmxrDu58pYAj8r9v'},
#    'href': 'https://api.spotify.com/v1/albums/5j1qqBBmxrDu58pYAj8r9v',
#    'id': '5j1qqBBmxrDu58pYAj8r9v',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732a74a83033b30c62f376058f',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022a74a83033b30c62f376058f',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512a74a83033b30c62f376058f',
#      'width': 64}],
#    'name': 'Shape of You (feat. Nyla & Kranium) [Major Lazer Remix]',
#    'release_date': '2017-02-24',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:5j1qqBBmxrDu58pYAj8r9v'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VZY0nxYMSNotbS7WjNVQy'},
#     'href': 'https://api.spotify.com/v1/artists/4VZY0nxYMSNotbS7WjNVQy',
#     'id': '4VZY0nxYMSNotbS7WjNVQy',
#     'name': 'Nyla',
#     'type': 'artist',
#     'uri': 'spotify:artist:4VZY0nxYMSNotbS7WjNVQy'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1LKo6ZA3RNvKtLa6zDu32S'},
#     'href': 'https://api.spotify.com/v1/artists/1LKo6ZA3RNvKtLa6zDu32S',
#     'id': '1LKo6ZA3RNvKtLa6zDu32S',
#     'name': 'Kranium',
#     'type': 'artist',
#     'uri': 'spotify:artist:1LKo6ZA3RNvKtLa6zDu32S'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/738wLrAtLtCtFOLvQBXOXp'},
#     'href': 'https://api.spotify.com/v1/artists/738wLrAtLtCtFOLvQBXOXp',
#     'id': '738wLrAtLtCtFOLvQBXOXp',
#     'name': 'Major Lazer',
#     'type': 'artist',
#     'uri': 'spotify:artist:738wLrAtLtCtFOLvQBXOXp'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 192000,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS1700228'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1KqvRRQd3lfM0pAlkGPrgD'},
#   'href': 'https://api.spotify.com/v1/tracks/1KqvRRQd3lfM0pAlkGPrgD',
#   'id': '1KqvRRQd3lfM0pAlkGPrgD',
#   'is_local': False,
#   'name': 'Shape of You (feat. Nyla & Kranium) - Major Lazer Remix',
#   'popularity': 55,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3563fa0c1a7187c946d7dcb827f3cf1c65126535?cid=2532039cdb304f01bb5366c20830cdc6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1KqvRRQd3lfM0pAlkGPrgD'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4sTQVOfp9vEMCemLw50sbu'},
#      'href': 'https://api.spotify.com/v1/artists/4sTQVOfp9vEMCemLw50sbu',
#      'id': '4sTQVOfp9vEMCemLw50sbu',
#      'name': 'Galantis',
#      'type': 'artist',
#      'uri': 'spotify:artist:4sTQVOfp9vEMCemLw50sbu'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6K5S3fWJ6logqsusWVaJUG'},
#    'href': 'https://api.spotify.com/v1/albums/6K5S3fWJ6logqsusWVaJUG',
#    'id': '6K5S3fWJ6logqsusWVaJUG',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2730ab4e483a469698633a70ce9',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e020ab4e483a469698633a70ce9',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048510ab4e483a469698633a70ce9',
#      'width': 64}],
#    'name': 'Shape of You (Galantis Remix)',
#    'release_date': '2017-02-10',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:6K5S3fWJ6logqsusWVaJUG'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4sTQVOfp9vEMCemLw50sbu'},
#     'href': 'https://api.spotify.com/v1/artists/4sTQVOfp9vEMCemLw50sbu',
#     'id': '4sTQVOfp9vEMCemLw50sbu',
#     'name': 'Galantis',
#     'type': 'artist',
#     'uri': 'spotify:artist:4sTQVOfp9vEMCemLw50sbu'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 195988,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBAHS1700196'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5H7CwzYZ60e7w69tX4ivQN'},
#   'href': 'https://api.spotify.com/v1/tracks/5H7CwzYZ60e7w69tX4ivQN',
#   'id': '5H7CwzYZ60e7w69tX4ivQN',
#   'is_local': False,
#   'name': 'Shape of You - Galantis Remix',
#   'popularity': 49,
#   'preview_url': 'https://p.scdn.co/mp3-preview/85217996d3bcfaf40f0fb7c9f93011889e65fab9?cid=2532039cdb304f01bb5366c20830cdc6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track
},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1dVWoeam7D1Zg6hB57pBE7'},
#   'href': 'https://api.spotify.com/v1/tracks/1dVWoeam7D1Zg6hB57pBE7',
#   'id': '1dVWoeam7D1Zg6hB57pBE7',
#   'is_local': False,
#   'name': 'Shape of You - NOTD Remix',
#   'popularity': 40,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fe1ab16bc5b70efaa724f9fb157b0621228290cc?cid=2532039cdb304f01bb5366c20830cdc6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1dVWoeam7D1Zg6hB57pBE7'},
#  {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#      'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#      'id': '6eUKZXaKkcviH0Ku9w2n3V',
#      'name': 'Ed Sheeran',
#      'type': 'artist',
#      'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/6y6RDTPqAox4sTHfy1piVX'},
#    'href': 'https://api.spotify.com/v1/albums/6y6RDTPqAox4sTHfy1piVX',
#    'id': '6y6RDTPqAox4sTHfy1piVX',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273821c7d10ad64f3960576623c',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02821c7d10ad64f3960576623c',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851821c7d10ad64f3960576623c',
#      'width': 64}],
#    'name': 'Shape of You (Yxng Bane Remix)',
#    'release_date': '2017-08-11',
#    'release_date_precision': 'day',
#    'total_tracks': 1,
#    'type': 'album',
#    'uri': 'spotify:album:6y6RDTPqAox4sTHfy1piVX'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/5AbLpsnTQVNB3OEadYiVrK'},
#     'href': 'https://api.spotify.com/v1/artists/5AbLpsnTQVNB3OEadYiVrK',
#     'id': '5AbLpsnTQVNB3OEadYiVrK',
#     'name': 'Yxng Bane',
#     'type': 'artist',
#     'uri': 'spotify:artist:5AbLpsnTQVNB3OEadYiVrK'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 207128,
#   'explicit': True,
#   'external_ids': {'isrc': 'GBAHS1700651'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/31OUf7myzRshUdO8aQpEPH'},
#   'href': 'https://api.spotify.com/v1/tracks/31OUf7myzRshUdO8aQpEPH',
#   'id': '31OUf7myzRshUdO8aQpEPH',
#   'is_local': False,
#   'name': 'Shape of You - Yxng Bane Remix',
#   'popularity': 45,
#   'preview_url': 'https://p.scdn.co/mp3-preview/32d7e040f784d66f787b117d4248cd0682b101a6?cid=2532039cdb304f01bb5366c20830cdc6',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:31OUf7myzRshUdO8aQpEPH'},
#  {'album': {'album_type': 'compilation',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#      'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#      'id': '0LyfQWJT6nXafLPZqxe9Of',
#      'name': 'Various Artists',
#      'type': 'artist',
#      'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
#     'FI',
#     'FJ',
#     'FM',
#     'FR',
#     'GA',
#     'GB',
#     'GD',
#     'GE',
#     'GH',
#     'GM',
#     'GN',
#     'GQ',
#     'GR',
#     'GT',
#     'GW',
#     'GY',
#     'HK',
#     'HN',
#     'HR',
#     'HT',
#     'HU',
#     'ID',
#     'IE',
#     'IL',
#     'IN',
#     'IS',
#     'IT',
#     'JM',
#     'JO',
#     'JP',
#     'KE',
#     'KG',
#     'KH',
#     'KI',
#     'KM',
#     'KN',
#     'KR',
#     'KW',
#     'KZ',
#     'LA',
#     'LB',
#     'LC',
#     'LI',
#     'LK',
#     'LR',
#     'LS',
#     'LT',
#     'LU',
#     'LV',
#     'MA',
#     'MC',
#     'MD',
#     'ME',
#     'MG',
#     'MH',
#     'MK',
#     'ML',
#     'MN',
#     'MO',
#     'MR',
#     'MT',
#     'MU',
#     'MV',
#     'MW',
#     'MX',
#     'MY',
#     'MZ',
#     'NA',
#     'NE',
#     'NG',
#     'NI',
#     'NL',
#     'NO',
#     'NP',
#     'NR',
#     'NZ',
#     'OM',
#     'PA',
#     'PE',
#     'PG',
#     'PH',
#     'PK',
#     'PL',
#     'PS',
#     'PT',
#     'PW',
#     'PY',
#     'QA',
#     'RO',
#     'RS',
#     'RU',
#     'RW',
#     'SA',
#     'SB',
#     'SC',
#     'SE',
#     'SG',
#     'SI',
#     'SK',
#     'SL',
#     'SM',
#     'SN',
#     'SR',
#     'ST',
#     'SV',
#     'SZ',
#     'TD',
#     'TG',
#     'TH',
#     'TL',
#     'TN',
#     'TO',
#     'TR',
#     'TT',
#     'TV',
#     'TW',
#     'TZ',
#     'UA',
#     'UG',
#     'US',
#     'UY',
#     'UZ',
#     'VC',
#     'VN',
#     'VU',
#     'WS',
#     'XK',
#     'ZA',
#     'ZM',
#     'ZW'],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2juq4nFUnEeP4JUmjHyNsP'},
#    'href': 'https://api.spotify.com/v1/albums/2juq4nFUnEeP4JUmjHyNsP',
#    'id': '2juq4nFUnEeP4JUmjHyNsP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2737b0404a2ac46a035c0d76e1e',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e027b0404a2ac46a035c0d76e1e',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048517b0404a2ac46a035c0d76e1e',
#      'width': 64}],
#    'name': 'Peaceful Piano',
#    'release_date': '2017-05-05',
#    'release_date_precision': 'day',
#    'total_tracks': 48,
#    'type': 'album',
#    'uri': 'spotify:album:2juq4nFUnEeP4JUmjHyNsP'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#     'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#     'id': '6eUKZXaKkcviH0Ku9w2n3V',
#     'name': 'Ed Sheeran',
#     'type': 'artist',
#     'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2ic47UrNAHRSZ82o0Y39vh'},
#     'href': 'https://api.spotify.com/v1/artists/2ic47UrNAHRSZ82o0Y39vh',
#     'id': '2ic47UrNAHRSZ82o0Y39vh',
#     'name': 'John McDaid',
#     'type': 'artist',
#     'uri': 'spotify:artist:2ic47UrNAHRSZ82o0Y39vh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4HQPu8xlD0YTKmUhCsty3a'},
#     'href': 'https://api.spotify.com/v1/artists/4HQPu8xlD0YTKmUhCsty3a',
#     'id': '4HQPu8xlD0YTKmUhCsty3a',
#     'name': 'Steve Mac',
#     'type': 'artist',
#     'uri': 'spotify:artist:4HQPu8xlD0YTKmUhCsty3a'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1ylcY77FWeSVQKh5et1VGp'},
#     'href': 'https://api.spotify.com/v1/artists/1ylcY77FWeSVQKh5et1VGp',
#     'id': '1ylcY77FWeSVQKh5et1VGp',
#     'name': 'Music Lab Collective',
#     'type': 'artist',
#     'uri': 'spotify:artist:1ylcY77FWeSVQKh5et1VGp'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
#    'GD',
#    'GE',
#    'GH',
#    'GM',
#    'GN',
#    'GQ',
#    'GR',
#    'GT',
#    'GW',
#    'GY',
#    'HK',
#    'HN',
#    'HR',
#    'HT',
#    'HU',
#    'ID',
#    'IE',
#    'IL',
#    'IN',
#    'IS',
#    'IT',
#    'JM',
#    'JO',
#    'JP',
#    'KE',
#    'KG',
#    'KH',
#    'KI',
#    'KM',
#    'KN',
#    'KR',
#    'KW',
#    'KZ',
#    'LA',
#    'LB',
#    'LC',
#    'LI',
#    'LK',
#    'LR',
#    'LS',
#    'LT',
#    'LU',
#    'LV',
#    'MA',
#    'MC',
#    'MD',
#    'ME',
#    'MG',
#    'MH',
#    'MK',
#    'ML',
#    'MN',
#    'MO',
#    'MR',
#    'MT',
#    'MU',
#    'MV',
#    'MW',
#    'MX',
#    'MY',
#    'MZ',
#    'NA',
#    'NE',
#    'NG',
#    'NI',
#    'NL',
#    'NO',
#    'NP',
#    'NR',
#    'NZ',
#    'OM',
#    'PA',
#    'PE',
#    'PG',
#    'PH',
#    'PK',
#    'PL',
#    'PS',
#    'PT',
#    'PW',
#    'PY',
#    'QA',
#    'RO',
#    'RS',
#    'RU',
#    'RW',
#    'SA',
#    'SB',
#    'SC',
#    'SE',
#    'SG',
#    'SI',
#    'SK',
#    'SL',
#    'SM',
#    'SN',
#    'SR',
#    'ST',
#    'SV',
#    'SZ',
#    'TD',
#    'TG',
#    'TH',
#    'TL',
#    'TN',
#    'TO',
#    'TR',
#    'TT',
#    'TV',
#    'TW',
#    'TZ',
#    'UA',
#    'UG',
#    'US',
#    'UY',
#    'UZ',
#    'VC',
#    'VN',
#    'VU',
#    'WS',
#    'XK',
#    'ZA',
#    'ZM',
#    'ZW'],
#   'disc_number': 1,
#   'duration_ms': 143400,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBF071700070'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/03lTWJC8DjEspw3tNQ0rxL'},
#   'href': 'https://api.spotify.com/v1/tracks/03lTWJC8DjEspw3tNQ0rxL',
#   'id': '03lTWJC8DjEspw3tNQ0rxL',
#   'is_local': False,
#   'name': 'Shape Of You',
#   'popularity': 26,
#   'preview_url': None,
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:03lTWJC8DjEspw3tNQ0rxL'}]

# %% [markdown]
# # Get spotify track ids for the missing songs

# %%
missing = pd.read_csv('to_scrape.csv')
missing = missing.drop(columns = ['Unnamed: 0'])

# %%
missing
# Out:
#                                                    url      WeekID  \
# 0    http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958
# 1    http://www.billboard.com/charts/hot-100/1995-1...   12/2/1995
# 2    http://www.billboard.com/charts/hot-100/1997-1...  10/11/1997
# 3    http://www.billboard.com/charts/hot-100/2006-0...    7/1/2006
# 4    http://www.billboard.com/charts/hot-100/2009-1...  10/24/2009
# ..                                                 ...         ...
# 876  http://www.billboard.com/charts/hot-100/1995-0...    7/8/1995
# 877  http://www.billboard.com/charts/hot-100/2016-1...  11/19/2016
# 878  http://www.billboard.com/charts/hot-100/2009-1...  11/14/2009
# 879  http://www.billboard.com/charts/hot-100/1998-0...    8/1/1998
# 880  http://www.billboard.com/charts/hot-100/2012-0...   3/24/2012
#
#      Week Position                                             Song_x  \
# 0                1                                   Poor Little Fool
# 1                1                                      One Sweet Day
# 2                1  Candle In The Wind 1997/Something About The Wa...
# 3                1                                Do I Make You Proud
# 4                1                                                  3
# ..             ...                                                ...
# 876              7                                   Scream/Childhood
# 877              7                                          24K Magic
# 878              8                                                  3
# 879              9                                       Ray Of Light
# 880             10                                         Part Of Me
#
#                          Performer_x  \
# 0                       Ricky Nelson
# 1         Mariah Carey & Boyz II Men
# 2                         Elton John
# 3                       Taylor Hicks
# 4                     Britney Spears
# ..                               ...
# 876  Michael Jackson & Janet Jackson
# 877                       Bruno Mars
# 878                   Britney Spears
# 879                          Madonna
# 880                       Katy Perry
#
#                                                 SongID  Instance  \
# 0                         Poor Little FoolRicky Nelson       1.0
# 1              One Sweet DayMariah Carey & Boyz II Men       1.0
# 2    Candle In The Wind 1997/Something About The Wa...       1.0
# 3                      Do I Make You ProudTaylor Hicks       1.0
# 4                                      3Britney Spears       1.0
# ..                                                 ...       ...
# 876    Scream/ChildhoodMichael Jackson & Janet Jackson       1.0
# 877                                24K MagicBruno Mars       1.0
# 878                                    3Britney Spears       1.0
# 879                                Ray Of LightMadonna       1.0
# 880                               Part Of MeKaty Perry       1.0
#
#      Previous Week Position  Peak Position  Weeks on Chart  ...  loudness  \
# 0                       NaN            1.0             1.0  ...       NaN
# 1                       NaN            1.0             1.0  ...       NaN
# 2                       NaN            1.0             1.0  ...       NaN
# 3                       NaN            1.0             1.0  ...       NaN
# 4                       NaN            1.0             1.0  ...       NaN
# ..                      ...            ...             ...  ...       ...
# 876                     5.0            5.0             4.0  ...       NaN
# 877                     6.0            5.0             4.0  ...       NaN
# 878                     8.0            1.0             4.0  ...       NaN
# 879                     8.0            5.0             4.0  ...       NaN
# 880                     5.0            1.0             4.0  ...       NaN
#
#      mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     NaN          NaN           NaN               NaN       NaN      NaN
# 1     NaN          NaN           NaN               NaN       NaN      NaN
# 2     NaN          NaN           NaN               NaN       NaN      NaN
# 3     NaN          NaN           NaN               NaN       NaN      NaN
# 4     NaN          NaN           NaN               NaN       NaN      NaN
# ..    ...          ...           ...               ...       ...      ...
# 876   NaN          NaN           NaN               NaN       NaN      NaN
# 877   NaN          NaN           NaN               NaN       NaN      NaN
# 878   NaN          NaN           NaN               NaN       NaN      NaN
# 879   NaN          NaN           NaN               NaN       NaN      NaN
# 880   NaN          NaN           NaN               NaN       NaN      NaN
#
#      tempo  time_signature     _merge
# 0      NaN             NaN  left_only
# 1      NaN             NaN  left_only
# 2      NaN             NaN  left_only
# 3      NaN             NaN  left_only
# 4      NaN             NaN  left_only
# ..     ...             ...        ...
# 876    NaN             NaN  left_only
# 877    NaN             NaN  left_only
# 878    NaN             NaN  left_only
# 879    NaN             NaN  left_only
# 880    NaN             NaN  left_only
#
# [881 rows x 28 columns]

# %% [markdown]
# The following lines print the artist & the song if the spotify API search failed.

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API
for song in missing.values: 
    artist = song[4]
    song = song[3]
    result = sp.search(q=f'artist:{artist} track:{song}')
    if len(result['tracks']['items']) <= 1:
        print(artist, song)
# Out:
# Mariah Carey & Boyz II Men One Sweet Day
# Elton John Candle In The Wind 1997/Something About The Way You Look Tonight
# Justin Timberlake Can't Stop The Feeling!
# Katy Perry Featuring Snoop Dogg California Gurls
# Major Lazer Featuring Justin Bieber & MO Cold Water
# Post Malone Featuring 21 Savage Rockstar
# Post Malone Featuring Ty Dolla $ign Psycho
# Lil Wayne Featuring Drake She Will
# Maroon 5 Featuring Wiz Khalifa Payphone
# Ariana Grande Featuring Iggy Azalea Problem
# Glee Cast Don't Stop Believin'
# Katy Perry Featuring Skip Marley Chained To The Rhythm
# Michael Jackson & Janet Jackson Scream/Childhood
# Jay-Z & T.I. Featuring Kanye West & Lil Wayne Swagga Like Us
# Justin Bieber Featuring Ludacris Baby
# Lil Wayne Featuring XXXTENTACION Don't Cry
# Duane Eddy His Twangy Guitar And The Rebels Rebel-'rouser
# Janet Jackson Runaway
# Lil Wayne Featuring Drake Right Above It
# Jane Child Don't Wanna Fall In Love
# Jane Child Don't Wanna Fall In Love
# Jane Child Don't Wanna Fall In Love
# Jane Child Don't Wanna Fall In Love
# Jane Child Don't Wanna Fall In Love
# Jane Child Don't Wanna Fall In Love
# Maroon 5 Featuring Kendrick Lamar Don't Wanna Know
# Post Malone Featuring 21 Savage Rockstar
# Maroon 5 Featuring Wiz Khalifa Payphone
# Ariana Grande Featuring Iggy Azalea Problem
# Justin Timberlake Can't Stop The Feeling!
# Major Lazer Featuring Justin Bieber & MO Cold Water
# Post Malone Featuring Ty Dolla $ign Psycho
# Janet Jackson Runaway
# Michael Jackson & Janet Jackson Scream/Childhood

# %% [markdown]
# Seems like we need to delete any occurrence of [Featuring, & and apostrophes] in the artist names and song titles in order to get results from the API.
#
# For the songs containign a slash, we'll only take the part before that.
#
# We also remove parentheses and all data within.
# df['name'].str.replace(r"\(.*\)","")
#
# For the artist field containing ' x ' (which means Featuring), we remove the ' x '.

# %%
missing['Performer_x'] = missing['Performer_x'].str.replace('&','')
missing['Performer_x'] = missing['Performer_x'].str.replace('\'','')
missing['Song_x'] = missing['Song_x'].str.replace('\'','')
missing['Performer_x'] = missing['Performer_x'].str.replace('Featuring','')

missing['Song_x'] = missing['Song_x'].str.split('/').str[0]
missing['Song_x'] = missing['Song_x'].str.replace(r"\(.*?\)","")

missing['Performer_x'] = missing['Performer_x'].str.replace(' x ',' ')
missing['Performer_x'] = missing['Performer_x'].str.replace(' X ',' ')

# %%
for song in missing.values:
    artist = song[4]
    song = song[3]
    result = sp.search(q=f'artist:{artist} track:{song}')
    if len(result['tracks']['items']) < 1:
        print(artist, song)
# Out:
# Duane Eddy His Twangy Guitar And The Rebels Rebel-rouser
# Duane Eddy His Twangy Guitar And The Rebels Rebel-rouser
# Duane Eddy His Twangy Guitar And The Rebels Rebel-rouser

# %%
def fill_id(track):
    if(track.Performer_x == 'Duane Eddy His Twangy Guitar And The Rebels'):
        return '4nAJtcmiyoL0ARY5WZY9IN'
    else: 
        result = sp.search(q=f'artist:{track.Performer_x} track:{track.Song_x}')
        if len(result['tracks']['items']) > 0:
            return result['tracks']['items'][0]['id']
        else: return

missing['spotify_track_id'] = missing.apply(lambda track:fill_id(track),axis=1)

# %%
missing.isnull().sum()

# %%
# We will filter out the 98 missing tracks
missing = missing[~missing['spotify_track_id'].isnull()].reset_index(drop=True)

# %% [markdown]
# # Get audio features for missing songs

# %% [markdown]
# sp.audio_features does not accept more than 100 ids, so we need to do 100 by 100

# %%
i = 0
audio_features = pd.io.json.json_normalize(sp.audio_features(missing['spotify_track_id'].values[i:i+100]))
while (i+100 < len(missing)):
    i = i + 100
    audio_features = audio_features.append(pd.io.json.json_normalize(sp.audio_features(missing['spotify_track_id'].values[i:i+100])), ignore_index=True)

plus = len(missing) % 100
audio_features = audio_features.append(pd.io.json.json_normalize(sp.audio_features(missing['spotify_track_id'].values[len(missing)-plus:len(missing)])), ignore_index=True)

# %%
audio_features = audio_features.drop(columns=['analysis_url', 'track_href', 'uri', 'type'])

# %%
cols_to_use = audio_features.columns.difference(missing.columns)
complete = missing.drop(columns='_merge').merge(right=audio_features, how='left', left_on='spotify_track_id', right_on='id', indicator=True, suffixes=('_y', '')).drop_duplicates().reset_index(drop=True)
complete = complete.drop(complete.filter(regex='_y$').columns.tolist(),axis=1)
complete
complete.to_csv('scraped.csv')
